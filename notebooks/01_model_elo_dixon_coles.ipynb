# %% [markdown]
# # 01 - Modelo Elo / Poisson / Dixon-Coles
#
# Este cuaderno acompaña la primera línea de modelos. La implementación productiva vive en `src/quiniela/models/` y se ejecuta con `scripts/run_model.py`.
#
# Estado actual:
#
# - `baseline_poisson`: implementado.
# - `elo_poisson`: implementado.
# - `elo_dixon_coles`: reservado para la siguiente iteración.

# %%
from pathlib import Path
import sqlite3

PROJECT_ROOT = Path.cwd().parent if Path.cwd().name == "notebooks" else Path.cwd()
DB_PATH = PROJECT_ROOT / "data" / "quiniela.db"
DB_PATH

# %%
conn = sqlite3.connect(DB_PATH)
conn.row_factory = sqlite3.Row
rows = conn.execute("""
SELECT model_id, match_number, team_a_name, team_b_name,
       expected_goals_a, expected_goals_b,
       p_team_a_win, p_draw, p_team_b_win,
       selected_score, selected_expected_points
FROM v_latest_model_predictions
WHERE status = 'ok'
ORDER BY model_id, match_number
LIMIT 12
""").fetchall()
[dict(row) for row in rows]

# %% [markdown]
# Comando reproducible desde la raíz del proyecto:
#
# ```powershell
# python scripts\run_model.py
# python scripts\generate_dashboard.py
# ```
